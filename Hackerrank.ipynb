# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandinih890/HackerRank/blob/main/Hackerrank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n, d = map(int, input().split())
arr = list(map(int, input().split()))

d = d % n
result = arr[d:] + arr[:d]

print(*result)
# Out:
# 5 4
# 1 2 3 4 5
# 5 1 2 3 4

# %%
n, k = map(int, input().split())
prices = list(map(int, input().split()))

prices.sort()

count = 0
total = 0

for price in prices:
    if total + price <= k:
        total += price
        count += 1
    else:
        break

print(count)
# Out:
# 7 50
# 1 12 5 111 200 1000 10
# 4

# %%
arr = list(map(int, input().split()))

total = sum(arr)

minimum = total - max(arr)
maximum = total - min(arr)

print(minimum, maximum)
# Out:
# 1 2 3 4 5
# 10 14
